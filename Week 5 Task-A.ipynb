# %%
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect('/content/sql-murder-mystery.db')

# %%
print(conn)

# %%
query_1 = '''
SELECT *
FROM crime_scene_report
WHERE city = "SQL City"
ORDER BY date;
'''
pd.set_option('display.max_colwidth', None)
pd.read_sql_query(query_1, conn)
# Out:
#        date     type  \
# 0  20170712    theft
# 1  20170820    arson
# 2  20171110  robbery
# 3  20180103  bribery
# 4  20180115  assault
# 5  20180115  assault
# 6  20180115   murder
# 7  20180215   murder
# 8  20180215   murder
#
#                                                                                                                                                                                                                                                               description  \
# 0              A lone hunter stalks the night, firing arrows into the Darkness.\n            There is no hiding, no escape. In the distance, the beast\n            falters, tethered to the void. The killing blow comes without\n            hesitation, without mercy.
# ...

# %%
query_2 = '''
SELECT *
FROM Person
WHERE address_street_name ='Northwestern Dr'
ORDER BY address_number desc;
'''

# %%
pd.read_sql_query(query_2, conn)[:5]
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 1  17729  Lasonya Wildey      439686            3824     Northwestern Dr
# 2  53890  Sophie Tiberio      957671            3755     Northwestern Dr
# 3  73368  Torie Thalmann      773862            3697     Northwestern Dr
# 4  96595   Coretta Cubie      303645            3631     Northwestern Dr
#
#          ssn
# 0  111564949
# 1  917817122
# 2  442830147
# 3  341559436
# 4  378403829

# %%
query_3 = '''
SELECT *
FROM Person
WHERE address_street_name ='Franklin Ave'
ORDER BY address_number desc;
'''

# %%
pd.read_sql_query(query_3, conn)[:5]
# Out:
#       id               name  license_id  address_number address_street_name  \
# 0  24737         Gema Nantz      273410            3968        Franklin Ave
# 1  84531     Edgar Mendieta      315790            3881        Franklin Ave
# 2  36328       Domenic Laun      971080            3809        Franklin Ave
# 3  34592  Cordell Lindamood      592762            3657        Franklin Ave
# 4  83003     Wilmer Casella      672050            3564        Franklin Ave
#
#          ssn
# 0  180545802
# 1  458847132
# 2  825329637
# 3  509890333
# 4  569057540

# %%
query_4 = '''
SELECT *
FROM get_fit_now_member as gf
WHERE Person_id = gf.Person_id
ORDER BY Person_id desc;
'''

# %%
pd.read_sql_query(query_4, conn)[:5]
# Out:
#       id  person_id                name  membership_start_date  \
# 0  D2KY6      99602    Joline Hollering               20170220
# 1  MYQ6A      99462      Darren Yahraus               20170712
# 2  RMX31      99277      Pia Ruthenberg               20171129
# 3  CGQ1A      99037  Adrienne Fleishman               20170718
# 4  0T622      98782     Sarina Overpeck               20171109
#
#   membership_status
# 0              gold
# 1            silver
# 2            silver
# 3           regular
# 4              gold

# %%
query_5 = '''
SELECT *
FROM drivers_license as dl
WHERE id = dl.id
ORDER BY id desc;
'''

# %%
pd.read_sql_query(query_5, conn)[:5]
# Out:
#        id  age  height eye_color hair_color  gender plate_number    car_make  \
# 0  999993   18      63     black      black  female       6UZO2O    Cadillac
# 1  999986   49      58     green       grey    male       F8F64H       Lexus
# 2  999981   67      69     brown       blue  female       1684K3  Land Rover
# 3  999940   71      61     green      green    male       1B8QN8  Mitsubishi
# 4  999923   19      77     amber      black  female       5L0ZI4         GMC
#
#      car_model
# 0      DeVille
# 1           LS
# 2          LR2
# 3      Eclipse
# 4  Sierra 3500

# %%
query_6 = '''
SELECT *
FROM get_fit_now_member as gf
WHERE membership_status = gf.membership_status
ORDER BY membership_status desc;
'''

# %%
pd.read_sql_query(query_6, conn)[:5]
# Out:
#       id  person_id                name  membership_start_date  \
# 0  2PN28      63823  Jeromy Heitschmidt               20180215
# 1  3A08L      32858        Mei Bianchin               20170401
# 2  156A7      79701     Marcelino Leard               20180428
# 3  X0643      15247      Shondra Ledlow               20170521
# 4  8T75D      86040       Shani Mcclard               20170430
#
#   membership_status
# 0            silver
# 1            silver
# 2            silver
# 3            silver
# 4            silver

# %%
## Now after analyzing all the above queries....##
query_7 = '''
SELECT p.*, ci.*
FROM drivers_license as dl
INNER JOIN person as p on dl.id = p.license_id
INNER JOIN get_fit_now_member as gf on p.id = gf.person_id
INNER JOIN get_fit_now_check_in as ci on gf.id = ci.membership_id
WHERE plate_number LIKE '%H42W%'
AND membership_status = 'gold'
AND check_in_date = 20180109
'''

# %%
pd.read_sql_query(query_7, conn)[:5]
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn membership_id  check_in_date  check_in_time  check_out_time
# 0  871539279         48Z55       20180109           1530            1700

# %%
query_8 = '''
INSERT INTO solution VALUES (1,'Jeremy Bowers');
SELECT value FROM solution;
'''
